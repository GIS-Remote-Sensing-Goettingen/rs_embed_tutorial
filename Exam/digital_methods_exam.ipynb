# %% [markdown]
# # M.EES.104: Digital Methods - Exam part II: programming task - Maize classification Eastern cape (Rene' Heim, Davide Mattioli)

# %% [markdown]
# ## Names of all students in team:

# %% [markdown]
# ## Work period: 16 July - 6 August
# ## Deadline and upload: __7 August 2026__

# %% [markdown]
# ## Instructions
#
# The task is presented in this Jupyter notebook and the same file __including your solution__ should be submitted.
#
# - Make sure all cells can be successfully executed in the order of appearance after all outputs have been cleared.
# - Include plenty of comments to explain what your code is supposed to do. You are required to show that you put some effort into solving the programming tasks.
# - Disclose sources and tools that you use for solving this programming task (which is legitimate). AI-detection tools may be applied during the assessment of your solution but make it transparent.
# - Rename the file incl. your last names. __Unnamed files will not be considered.__
# - Upload the file in the Stud.ip folder ``Exam_programming_task_submission``.
# - The lecturer whose task you chose will get in contact to fix a date for an oral presentation of your jupyter notebook. The presentation includes explaining how the code works and discussing results.

# %% [markdown]
# ## Maize classification in eastern cape

# %% [markdown]
# ### Description of Scientific Setting and Objective
#
# The objective of this project is to build a **multi-class landscape classification algorithm** for the Eastern Cape region of South Africa. The model will classify Sentinel-2 satellite imagery into three land-cover classes: **maize regions**, **urban regions**, and **grassland regions**.
#
# The goal is to compare how well different input features, such as spectral bands, vegetation indices, and Tessera embeddings, can distinguish between agricultural maize areas, built-up urban areas, and natural or semi-natural grassland landscapes.

# %% [markdown]
# ### Data
# You can download the sentinel 2 data using the python library cubo. and use QGIS to make the labels for your model
#
# **Date range:** 15 February – 10 April
#
# **Suggested region:** Eastern Cape maize-growing areas, South Africa
#
# **Suggested coordinates:**
#
# * Mthatha / OR Tambo: `-31.5864, 28.7900`
# * Qumbu / OR Tambo: `-31.1683, 28.8765`
# * Tsolo / OR Tambo: `-31.3194, 28.7548`
# * Matatiele / Alfred Nzo: `-30.3621, 28.8014`
# * Butterworth / Amathole: `-32.3323, 28.1446`
# * Cofimvaba / Chris Hani: `-32.0010, 27.5800`

# %% [markdown]
# ### Subtasks
#
# For each subtask, explain what you observe and what you do not observe. Justify the choices you make, and briefly discuss the advantages and disadvantages of the chosen approach where relevant.
#
# **1) Create meaningful labels**
# Create labels for the three classes: **maize**, **urban**, and **grassland**. Explain how the labels were created, what can be observed from them, and what possible label uncertainties may exist.
#
# **2) Visualize the Sentinel-2 regions and analyze reflectance distributions**
# Visualize the selected Sentinel-2 regions for the three classes: **maize**, **urban**, and **grassland**. Plot RGB or false-colour composites to inspect the study areas visually. Then compare the reflectance distributions of different Sentinel-2 bands for each class using plots such as histograms or boxplots. Report descriptive statistics, including the mean, median, standard deviation, minimum, and maximum reflectance values. Discuss which bands show clear differences between the classes and which bands overlap, and explain how this could affects the classification task.
#
# **3) Train and test a Random Forest model using Sentinel-2 spectral bands**
# Train and test a Random Forest classifier using the Sentinel-2 spectral bands as input features. Report the results using a confusion matrix, F1 score, accuracy, precision, and recall. Plot the classification map. Discuss which classes are classified well and which classes are confused.
#
# **Hint:** Remember to divide the data into **training**, **validation**, and **testing** sets using a **spatial split**. Avoid using only a random pixel split, because nearby pixels can be very similar and may cause overfitting or overly optimistic accuracy results.
#
#
# **4) Create and plot at least three spectral indices**
# Calculate and plot at least three spectral indices. Explain what each index shows, why it is useful for this classification task, and what its limitations are.
#
# **5) Train and test a combined model using bands and indices**
# Train and test a Random Forest model using both spectral bands and spectral indices. Report the results and plot the classification map. Discuss whether combining features improves the classification and why.
#
# **6) Train and test a model using Tessera embeddings**
# Use Tessera embeddings as input features for a Random Forest classifier. Report the results using the same evaluation metrics and plot the classification map. Discuss how the Tessera-based results compare with the Sentinel-2-based models.
#
# **7) Bonus: Explore model improvement**
# Try one or more ways to improve the classification model. Explain what was changed, what you observed, and whether the results improved.

# %% [markdown]
# ## Your solution
